# %% [markdown]
# # Complete Retraining Pipeline for MaSIF-Neosurf
#
# This notebook documents the complete workflow to retrain both neural networks in MaSIF-Neosurf:
# 1. **MaSIF-ppi-search NN** (descriptor generation)
# 2. **AlignmentEvaluationNN** (alignment scoring)

# %% [markdown]
# ## Part 1: Retrain MaSIF-ppi-search NN (Descriptor Generator)
#
# ### Prerequisites
# - Training dataset of protein-protein complexes (PDB files)
# - List files defining training/validation/test splits
#
# ### Step 1.1: Data Preparation
#
# Navigate to masif_ppi_search folder:
# ```bash
# cd masif/data/masif_ppi_search
# ```
#
# Prepare raw data (surfaces, features):
# ```bash
# sbatch data_prepare.slurm
# ```
#
# **What this does:**
# - Downloads PDB files
# - Triangulates molecular surfaces
# - Computes geometric and chemical features
# - Generates precomputation data (polar coordinates, etc.)
#
# **Outputs:**
# - `ply_chains/*.ply` - Surface meshes
# - `pdb_chains/*.pdb` - Individual chain PDBs
# - `01-benchmark_pdbs/precomputation_12A/*/*.npy` - Precomputed features
#
# ---
#
# ### Step 1.2: Cache Training Data
#
# Cache the training data for masif_ppi_search:
# ```bash
# sbatch cache_nn.slurm  # Or run cache_nn.sh
# ```
#
# **What this does:**
# - Loads precomputed features for all training proteins
# - Samples positive (binder) and negative (non-binder) pairs
# - Saves cached data as `.npy` files
#
# **Outputs:**
# - `nn_models/sc05/cache/binder_*.npy` - Binder features
# - `nn_models/sc05/cache/pos_*.npy` - Positive site features
# - `nn_models/sc05/cache/neg_*.npy` - Negative site features
# - `nn_models/sc05/cache/*_idx.npy` - Train/val/test indices
#
# ---
#
# ### Step 1.3: Train MaSIF-ppi-search NN
#
# Train the descriptor generation network:
# ```bash
# sbatch masif_ppi_search_train.slurm
# ```
#
# **Training configuration:**
# - Network: Geometric CNN with rotation equivariance
# - Loss: Siamese contrastive loss (push/pull descriptors)
# - Output: 16-dimensional descriptors per vertex
# - Duration: ~24-48 hours (depends on dataset size)
#
# **Outputs:**
# - `nn_models/sc05/all_feat/model_data/model.*` - Trained weights
#
# ---
#
# ### Step 1.4: Generate Descriptors with New Model
#
# Run inference with the newly trained model:
# ```bash
# sbatch compute_descriptors.slurm
# ```
#
# **What this does:**
# - Loads the trained MaSIF-ppi-search weights
# - Runs inference on all proteins
# - Generates 16D descriptors for each surface vertex
#
# **Expected output per protein complex:**
# ```
# descriptors/sc05/all_feat/PDBID_CHAIN1_CHAIN2/
# ├── p1_desc_straight.npy    # Chain 1 descriptors (normal)
# ├── p1_desc_flipped.npy      # Chain 1 descriptors (flipped for complementarity)
# ├── p2_desc_straight.npy     # Chain 2 descriptors (normal)
# └── p2_desc_flipped.npy      # Chain 2 descriptors (flipped)
# ```

# %% [markdown]
# _________
# ##############################################################################
#
# ##############################################################################

# %% [markdown]
# ## Part 2: Retrain AlignmentEvaluationNN (Alignment Scorer)
#
# **Prerequisites:** Descriptors from Part 1 (or existing descriptors)
#
# Navigate to masif_seed_search folder:
# ```bash
# cd masif_seed_search/data/scoring_nn
# ```
#
# ---
#
# ### Step 2.1: Generate Alignment Training Data
#
# Generate alignments with RMSD labels:
# ```bash
# sbatch make_transformations_12A.slurm
# ```
#
# **What this does:**
# - For each protein complex in training set:
#   - Extracts target patch (p1) and source patches (p2)
#   - Performs descriptor matching
#   - Aligns patches using RANSAC
#   - Computes RMSD to ground truth
#   - Saves alignment data
#
# **Outputs** (per protein):
# ```
# training_data_12A_seed_benchmark/PDBID_CHAIN1_CHAIN2/
# ├── aligned_source_patches.npy          # Aligned coordinates
# ├── aligned_source_patches_normals.npy  # Surface normals
# ├── aligned_source_patches_descs_0.npy  # Descriptors
# ├── aligned_source_patches_dists_to_target_atoms.npy  # Atom distances
# ├── source_patch_rmsds.npy              # RMSD labels (< 2.0 = positive)
# ├── target_patch.npy                    # Target patch coordinates
# └── ... (more metadata)
# ```
#
# **Duration:** ~1-2 hours per protein (parallelized via SLURM array)
#
# ---
#
# ### Step 2.2: Precompute Features
#
# Extract 4 features for neural network input:
# ```bash
# sbatch prepare_features_12A.slurm
# ```
#
# **What this does:**
# - For each alignment, compute:
#   1. `1/distance` - Spatial proximity
#   2. `1/descriptor_distance` - Descriptor similarity
#   3. `normal_dot_product` - Surface orientation
#   4. `1/vertex_to_atom_distance` - Atom proximity
# - Save as `features.npy`
#
# **Outputs:**
# ```
# training_data_12A_seed_benchmark/PDBID_CHAIN1_CHAIN2/
# └── features.npy  # Shape: (n_alignments, n_points, 4)
# ```
#
# ---
#
# ### Step 2.3: Train AlignmentEvaluationNN
#
# Train the alignment scoring network:
# ```bash
# sbatch train_nn.slurm
# ```
#
# **Training configuration:**
# - Network: PointNet-style (1D Conv + Global Pooling)
# - Task: Binary classification (RMSD < 2.0 Å = positive)
# - Input: (max_npoints=200, n_features=4)
# - Output: Probability of good alignment
# - Class ratio: 1 positive : 100 negatives
# - Epochs: 50
# - Duration: ~2-4 hours
#
# **Outputs:**
# - `models_std/weights_12A_0123.*` - Trained AlignmentEvaluationNN weights
#
# ---
#
# ### Step 2.4: Test the Trained Model
#
# Evaluate on test set:
# ```bash
# ./test_nn.sh
# ```
#
# **What this does:**
# - Loads trained weights
# - Evaluates on test proteins
# - Computes ROC AUC score
# - Generates `test_network.pdf` with score distributions

# %%
# Complete Retraining Pipeline Flowchart

"""
╔═══════════════════════════════════════════════════════════════════════╗
║           PART 1: RETRAIN MaSIF-ppi-search NN                         ║
║           (Descriptor Generation Network)                             ║
╚═══════════════════════════════════════════════════════════════════════╝

┌─────────────────────────────────────────────────────────────────┐
│ Step 1.1: Data Preparation                                      │
│ Location: masif/data/masif_ppi_search                          │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
        sbatch data_prepare.slurm
                     │
         ┌───────────┴────────────┐
         │ data_prepare_one.sh    │
         │ - Download PDBs        │
         │ - Triangulate surfaces │
         │ - Compute features     │
         │ - Precompute coords    │
         └───────────┬────────────┘
                     │
                     ▼
        OUTPUTS: .ply, .pdb, precomputation/*.npy

┌─────────────────────────────────────────────────────────────────┐
│ Step 1.2: Cache Training Data                                   │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
        sbatch cache_nn.slurm
                     │
         ┌───────────┴────────────────┐
         │ Sample binder/non-binder   │
         │ pairs from training set    │
         │ Save to cache/             │
         └───────────┬────────────────┘
                     │
                     ▼
        OUTPUTS: nn_models/sc05/cache/*.npy

┌─────────────────────────────────────────────────────────────────┐
│ Step 1.3: Train MaSIF-ppi-search NN                             │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
     sbatch masif_ppi_search_train.slurm
                     │
         ┌───────────┴────────────────┐
         │ Train geometric CNN        │
         │ Siamese network            │
         │ Learn 16D descriptors      │
         │ ~24-48 hours               │
         └───────────┬────────────────┘
                     │
                     ▼
        OUTPUTS: nn_models/sc05/all_feat/model_data/model.*

┌─────────────────────────────────────────────────────────────────┐
│ Step 1.4: Generate Descriptors with New Model                   │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
     sbatch compute_descriptors.slurm
                     │
         ┌───────────┴────────────────┐
         │ Run inference with         │
         │ trained model              │
         │ Generate descriptors       │
         └───────────┬────────────────┘
                     │
                     ▼
        OUTPUTS: descriptors/sc05/all_feat/*/p{1,2}_desc_{straight,flipped}.npy


╔═══════════════════════════════════════════════════════════════════════╗
║           PART 2: RETRAIN AlignmentEvaluationNN                       ║
║           (Alignment Scoring Network)                                 ║
╚═══════════════════════════════════════════════════════════════════════╝

┌─────────────────────────────────────────────────────────────────┐
│ Step 2.1: Generate Alignment Training Data                      │
│ Location: masif_seed_search/data/scoring_nn                    │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
     sbatch make_transformations_12A.slurm
                     │
         ┌───────────┴────────────────┐
         │ Match descriptors          │
         │ Align with RANSAC          │
         │ Compute RMSD labels        │
         │ Save alignment data        │
         └───────────┬────────────────┘
                     │
                     ▼
        OUTPUTS: training_data_12A_seed_benchmark/*/{aligned_*.npy, *_rmsds.npy}

┌─────────────────────────────────────────────────────────────────┐
│ Step 2.2: Precompute Features                                   │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
     sbatch prepare_features_12A.slurm
                     │
         ┌───────────┴────────────────┐
         │ Extract 4 features:        │
         │ - 1/distance               │
         │ - 1/desc_distance          │
         │ - normal_dot_product       │
         │ - 1/atom_distance          │
         └───────────┬────────────────┘
                     │
                     ▼
        OUTPUTS: training_data_12A_seed_benchmark/*/features.npy

┌─────────────────────────────────────────────────────────────────┐
│ Step 2.3: Train AlignmentEvaluationNN                           │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
        sbatch train_nn.slurm
                     │
         ┌───────────┴────────────────┐
         │ Train PointNet-style net   │
         │ Binary classification      │
         │ 1:100 pos:neg ratio        │
         │ 50 epochs                  │
         └───────────┬────────────────┘
                     │
                     ▼
        OUTPUT: models_std/weights_12A_0123.*

┌─────────────────────────────────────────────────────────────────┐
│ Step 2.4: Test Model                                            │
└────────────────────┬────────────────────────────────────────────┘
                     │
                     ▼
        ./test_nn.sh
                     │
                     ▼
        OUTPUT: test_network.pdf, ROC AUC score


╔═══════════════════════════════════════════════════════════════════════╗
║           SUMMARY: TWO NEURAL NETWORKS                                ║
╚═══════════════════════════════════════════════════════════════════════╝

MaSIF-ppi-search NN:
  Input:  Surface features (geometry + chemistry)
  Output: 16D descriptor vectors
  Task:   Metric learning (siamese network)
  Use:    Find similar/complementary surfaces

AlignmentEvaluationNN:
  Input:  4 alignment features per point
  Output: Probability of good alignment (0-1)
  Task:   Binary classification
  Use:    Score alignment quality
"""

# %% [markdown]
# ## Quick Reference Commands
#
# ### Full Retraining (Both Networks)
#
# ```bash
# # Part 1: MaSIF-ppi-search
# cd masif/data/masif_ppi_search
# sbatch data_prepare.slurm        # Wait for completion
# sbatch cache_nn.slurm             # Wait for completion
# sbatch masif_ppi_search_train.slurm  # ~24-48 hours
# sbatch compute_descriptors.slurm  # Wait for completion
#
# # Part 2: AlignmentEvaluationNN
# cd ../../masif_seed_search/data/scoring_nn
# sbatch make_transformations_12A.slurm  # Wait for completion
# sbatch prepare_features_12A.slurm      # Wait for completion
# sbatch train_nn.slurm                  # ~2-4 hours
# ./test_nn.sh
# ```
#
# ### Partial Retraining (AlignmentEvaluationNN only)
#
# If you already have descriptors from a trained MaSIF-ppi-search model:
#
# ```bash
# cd masif_seed_search/data/scoring_nn
# sbatch make_transformations_12A.slurm  # Wait for completion
# sbatch prepare_features_12A.slurm      # Wait for completion
# sbatch train_nn.slurm
# ./test_nn.sh
# ```
#
# ### File Locations After Training
#
# ```
# masif/data/masif_ppi_search/
# ├── nn_models/sc05/all_feat/model_data/
# │   └── model.*                          # ← MaSIF-ppi-search weights
# └── descriptors/sc05/all_feat/
#     └── PDBID_CHAIN1_CHAIN2/*.npy       # ← Generated descriptors
#
# masif_seed_search/data/scoring_nn/
# ├── training_data_12A_seed_benchmark/
# │   └── PDBID_CHAIN1_CHAIN2/*.npy       # ← Alignment training data
# └── models_std/
#     └── weights_12A_0123.*               # ← AlignmentEvaluationNN weights
# ```

# %% [markdown]
# ## Key Differences Between the Two Networks
#
# | Aspect | MaSIF-ppi-search NN | AlignmentEvaluationNN |
# |--------|--------------------|-----------------------|
# | **Purpose** | Generate surface descriptors | Score alignment quality |
# | **Input** | Raw surface features | Alignment features |
# | **Input dim** | (n_vertices, 5) | (n_points, 4) |
# | **Architecture** | Geometric CNN (polar coords) | PointNet (1D Conv + pooling) |
# | **Output** | 16D descriptor vector | Binary probability (0-1) |
# | **Training** | Siamese/metric learning | Binary classification |
# | **Loss** | Contrastive loss | Cross-entropy |
# | **Training data** | Binder/non-binder pairs | Alignment RMSD labels |
# | **Use in search** | Descriptor matching (offline) | Quality scoring (online) |
# | **Training time** | ~24-48 hours | ~2-4 hours |
#
# ## Important Notes
#
# ### Dependency Chain:
# ```
# MaSIF-ppi-search weights
#     ↓ (generates)
# Descriptors (.npy files)
#     ↓ (used to create)
# Alignment training data
#     ↓ (used to train)
# AlignmentEvaluationNN
# ```
#
# **⚠️ Critical**: If you retrain MaSIF-ppi-search with different hyperparameters or data, you MUST regenerate descriptors AND regenerate alignment training data before retraining AlignmentEvaluationNN!
#
# ### When to Retrain Each Network:
#
# **Retrain MaSIF-ppi-search when:**
# - Using a different training dataset
# - Adapting to a specific protein family
# - Incorporating new surface features
#
# **Retrain AlignmentEvaluationNN when:**
# - Using descriptors from a retrained MaSIF-ppi-search
# - Changing alignment algorithm parameters
# - Adjusting quality criteria (e.g., RMSD threshold)
